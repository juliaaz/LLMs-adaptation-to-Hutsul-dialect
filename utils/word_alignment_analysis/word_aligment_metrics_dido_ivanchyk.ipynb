# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/yuliiamaksymyuk/Library/Python/3.9/lib/python/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/yuliiamaksymyuk/Library/Python/3.9/lib/python/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yuliiamaksymyuk/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/yuliiamaksymyuk/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/yuliiamaksymyuk/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)

# %%
import json
import pandas as pd
import csv

def convert_json_to_alignment(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as file:
        data = json.load(file)

    aligned_sentences = []
    for item in data:
        hut_text = item['hut']
        ukr_text = item['ukr']
        aligned_sentences.append(f"{hut_text} ||| {ukr_text}")

    with open(output_file, 'w', encoding='utf-8') as file:
        for sentence in aligned_sentences:
            file.write(sentence + '\n')

def convert_csv_to_alignment(input_file, output_file):
    aligned_sentences = []
    with open(input_file, 'r', encoding='utf-8') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        for row in csv_reader:
            hut_text = row['Sentence']
            ukr_text = row['Synthetic_Sentence']
            aligned_sentences.append(f"{hut_text} ||| {ukr_text}")

    with open(output_file, 'w', encoding='utf-8') as file:
        for sentence in aligned_sentences:
            file.write(sentence + '\n')

convert_json_to_alignment('ivanchyk.json', 'corpus_ivanchyk.txt')

# %%
same_position_count = 0
different_position_count = 0

with open('symmetrized.align', 'r') as file:
    for line in file:
        alignments = line.strip().split()
        
        for alignment in alignments:
            source, target = map(int, alignment.split('-'))
            if source == target or source == target+1 or source == target-1:
                same_position_count += 1
            else:
                different_position_count += 1

print(f"Words aligned in the same position: {same_position_count}")
print(f"Words aligned in different positions: {different_position_count}")

# %%
sentence_pairs = []

with open('corpus_ivanchyk.txt', 'r', encoding='utf-8') as file:
    for line in file:
        print(line.strip())
        source, target = line.strip().split(' ||| ')  # Splitting by ' ||| '
        
        source_words = source.split()
        target_words = target.split()
        
        source_lengths = [len(word) for word in source_words]
        target_lengths = [len(word) for word in target_words]
        
        sentence_pairs.append((source_lengths, target_lengths))
# Out:
# Ось ми його зараз… ||| Леда смо га леда...
# Але це, звичайно, неможливо ||| Цисе, ашош, гляба, айбо
# Чи що він думав? ||| Ци шо вин гадав сми?
# Чи людина щось може ||| Ци шош літній.
# тут тільки трохи ще.. ||| Іно маленціо шє.
# Але я відаю її ||| Айбо також свідчим ї.
# Людина нічого не може ||| Людьина ни хібна.
# Це зовсім добрий бінокль ||| Цисе је велик окян
# Все це так ясно.. ||| Ну ладно, я зрозумів.
# Цікаво, як це сталося ||| Верег би це трафилося.
# Очевидно, треба звідси танцювати ||| Тря́к на вас вици данцувати.
# Через те, що сталося ||| Тото, чіріз шо трафилося.
# Ось тут починається друга частина моєї розповіді ||| Леда гир зачиняї друга буката моєї повісти.
# Але все це дурниці ||| Айбо все ці се бандити.
# Його почало страшно нудити ||| Зачєло пудно млоїти після того, як я побачив того дідуся.
# Я подумав, що таки так ||| ЙА подумав, шо йо.
# Саме тут прийшла підмога ||| Таки раптом прийшов допоміжний гір!
# Думаю, що саме мені ||| Гадкува, шо акурат мині
# Поки що це його мрія ||| Цісу шо заків го мрія.
# Ближче вона чи далі ||| Ближче не буду
# О, це хитрий дядько ||| АДЬИ, вуйко штудерний цисе.
# Я давно тебе думаю ||| ЙА єк давнєє єу гадкую
# Ось я повернуся додому ||| Леда вернуласи ід'хати.
# Щоб все мені збулося ||| Абесте всьо відновчало си
# Але раніше він все-таки заговорить ||| Аби давніше всьо-прем вин заговорить.
# "Чи, може, він грає?" ||| Ци, міцний, вин граєш?
# Але той вітер догнав його тепер ось тут.. ||| Той легіт догнав, а шо тепер леда гир.
# Він мав намір умерти ||| Вин мау хмарні плани, мабуть, засну.
# Людина нічого не може!.." ||| Людем нич не годит!..
# Тут щось не так ||| Шош йо не гір
# Він щось справді знає ||| Вин шох варе.
# Йому справді здається, що це не він іде ||| Йиму надійно відомо, що це не його вина.
# Але це таки остання ||| Aybo tse premm poslydna.
# Це все його книги" ||| Єк сі всьо єй книжічьки.
# Там корова, свіже молоко ||| Добрий день, як ви проводите час?
# Так він думав раніше ||| Йо вин давніше гадав сми.
# Я хочу бути коло тебе ||| Я за прошлым восклицанием венеть буду.
# Кажуть, хлопець один винен ||| Говори, хлопец оден вичний.
# Він ще може її побачити ||| Вин має цінність у іконі.
# Колись поїду до неї ||| Колис поїду ід ню на автобусі.
# Миттю зійшлися до неї ||| Начес сходили ід ню
# Що він може сказати ||| Що він варт заспокоїти.
# Так, так, саме "Він" ||| "Вот так, вот так, сам "Вин"
# Так, він обминав ім'я.. ||| Йо, він обійшов мене.
# "Звідки Микола все знає?" ||| "Иків Микольцьо чи всьо знаї?"
# Треба йти від ями ||| Три вида гели.
# Як це все страшно!. ||| Єк цисе всьо пудно!
# Але ось що цікаве.. ||| Але бо леда шо кортєчє..
# Мені дуже хочеться закінчити писати ||| Майґ спрузэс забыл дапавінку.
# Що я поки що непотріб ||| Шо йа це.
# Він один, ти одна… ||| Вин оден, тьи онна, наша.
# Він не може цього!. ||| Вин не вартий того!
# Між іншим, мати дуже хочуть тебе побачити ||| Мижи іншим, віршем дана нам моя душа, у ній ти зможеш мене відчути.
# Це через тебе її ||| Цісе чіріз тє ї, дес німа.
# Але вийти не може ||| Не годен вступити Айбо.
# Але не може бути ||| Айбо не годен відбили!
# Хто ти є: людина чи вівця ||| Хьто ца буют: людьина ци вивця
# Аби скоріше до хати" ||| Іди-и-и би в хату, бо з вами довше можна набути у моїй хаті.
# хто знає, як краще ||| хто знаї, єк красше
# Ось тут, біля вікна ||| Леда гир, підільно вікна.
# Він мені як батько ||| Вин є дешою.
# Потім — якесь череп'я.. ||| Витак — йкес черіп'є.
# Але зараз йому треба йти ||| Айбо леду йиму тро іти.
# Щоб мав що втрачати ||| Мөїште арха вон апавліюш.
# Я хочу тебе бачити.. ||| Iщоб пізнати тебе глибше.
# Певно, є якась причина ||| Ретенно, єк причіна буютьось.
# Видно, що брати недавно зустрілися ||| Бачив, як брати колись розводилися.
# Це є сьогодні, зараз ||| Цисе дзянь сёнь, леда
# А тепер ось ці, може, так само розстріляють його ||| А тіпер леда отсі, годен, йо само розстріляють го.
# Адже те, що я кажу, розуміється саме собою ||| Точно так, що я ка'юсь, розуміється само собою.
# Рушниця, як дівка, — треба до неї приноровитися ||| Кожен день по багатьох зломи прамавляўшы, пазнаёўшы, што ачоваць...
# Але справа раптом повернулась до нього зовсім несподівано ||| Ойбо тепер знову звернулась до нього впусте.
# Щасливий батько, весела мати, Настала згода, прийшло довір'я ||| Шісливий дьидик, жертівлива неня, Це настав день, прийшов час довіри.
# Але від цього йому стало ще тяжче ||| Айбо вид сего йиму стало шє тєшше.
# Може, вона має до нього якийсь жаль ||| Годен, уна має ід нього йикийс жєль.
# (Саме вони, ті, що прийшли до нього.) ||| «Хyi, тоти, шо прийшли ід нього.»
# Я думаю, що то збирається великий дощ ||| ЙА так надсідно, шо то збираїсі теньґий дошь
# Він вибрав місце — ось тут, о ||| Вин вибрав кусок – лист гір, ад’ї.
# Але ще краще, що ти вмієш думати ||| Айбо шо, шо тьи вмієш дуфати.
# Ну ніби лампочка, свічка або малесенький ліхтарик ||| Отік лямпчкою, свчкою або міціцькм лямпічкою.
# Так, ніби те все від тебе залежить ||| Йо, тоти вид всього залежить.
# Що в тебе тут, жінка чи дитина ||| Шо в тє гир, чілідина ци бахурчік, як це можна терпіти.
# І вона не може до тебе прийти ||| І не знати, коли шє отак си зъєднатися.
# Але ж це ми тільки тут так ||| Oi may obisemo fig isio nay.
# Я так і думав, що він там ||| Шо ЙА, шо і гадав сми, шо вин генде.
# Тільки вона вхопила, Микола зверху на неї.. ||| Іно було видно, що Микольцьо перехитрив нею.
# Він все думав, що перебуває тут випадково.. ||| Вин нічога сьо не знав, що перебуває гир непричком.
# Я повторюю, що мені обов'язково треба розповісти ||| ЙА мав намір сказати, але зціповків, бо тоді у скриню звідкнув тричі поспіль «гав, гав, гав» пес.
# Сьогодні, завтра, через місяць — те саме ||| Сьогодні, завтра, через місяць — все точно.
# А може, і справді хто думав пограбувати ||| А дола, шо кхьо дадав сми сполокати
# Але це, може, тому, що боїться розправи ||| Шо Айбо цисе, годен, тимунь, шо боїтси розправи.
# Ти хочеш сказати, що це ще небагато ||| "Тьи ващіз сєзча, шо шє кришечка."
# Мені здається, що він уже кається ||| Мині отєк, шо вин вже жалкує.
# Аж тут ще одна несподівана напасть ||| Аш гир шє онна дуже несподівана увага
# Одна нога тут, а друга там ||| Школа бела стена, а ученици весели.
# Хоч мені здається, що воно чуже ||| Хоч мині здається, шо воно надто склизьке.
# Через якийсь час йому стало легше ||| Чіріз йикийс лекше стало.
# ну, як так сказати, — норовистий.. ||| Говори, бо ни єк ти говориш, то відразу буду я з тобою говорити.
# Тут щось вона, ця дівчина, переборщила" ||| Шош здорова, що завзята, зашкварила.
# І ось саме тому "життя погане" ||| Лиш я леда акурат нїтом "житє нієке".
# Він, мабуть, думав, що ми голопуцьки ||| Він, бачив, розумів, що маємо на увазі.
# Все це мені не до вподоби ||| Всьо траба было забуцяць.
# Аж поки ніж став, мов бритва ||| Най стане день ясний, тош сам я буду.
# Очевидно, вони були щирі між собою ||| Видико, уни були шшірі мижи собов.
# Що ти ще тут маєш говорити ||| Шо тьи шє мусиш приказувати
# Як добре я пригадую той склеп ||| Єк сьо вже я ненадоїли!
# Але справа така, що краще тут ||| Ага, цікава така, шо крашше гир.
# Але що сталося: тихо, аж боляче ||| Айбо як враз ось таке: тихо, але дуже болюче.
# (Це таки справді якась інша раса!) ||| (Шуте крас бита йбас омба фасо!)
# Як кажуть: нехай вам здоров'я прибуде ||| Єк вам здоров'ячка прибуде!
# А може, йому треба було вигадувати ||| А годен, йиму відстудеровувати.
# Звідки Андрій про все те знає? ||| Іків Андрусик про всьо тото знаї?
# Звідки він прийшов на це подвір'я ||| Иків вин прийшов на задвірюшко
# Трохи не так, але дуже подібно ||| Мало не йо, айбо моць подібно.
# Місяць тому вона говорила те саме ||| Місіц тимунь говорила акурат уна.
# Ні, це тільки так йому здається ||| Ні, цисе іно йо йиму отєк.
# Треба швидко впоратись: гуртом, як один ||| Тремто вчитись: кожен сам.
# Хто швидше — ті чи вона ||| Хьто кращий — той чи унаше
# Ось це і є вона, Смерть ||| Цисе і буют уна вивідав, Авс.
# Уявили, що тут відбувається щось цікаве ||| Імажині вас, як авто шугає по шосе.
# Так, як тільки тут уміють париться ||| Йо, єк іно ни любить гір уміють паритися.
# Це дуже добре, що ми договорились.. ||| Це жодним чином не відповідає угоді, яку ми уклали.
# Ось тут зараз має бути закрут ||| Леда гир леда хай має абиде закрут.
# — Вибачай тільки, що більше нічого.. ||| — Вібач єні, що краще ніч.
# Доля— це щось таке, як хуртовина ||| Фант— цисе шош таке, єк фуфелаю
# як його звали, забув зовсім ім'я ||| єго ім'я забув, схоже мені.
# Але тут же відмовився від цього ||| Хлопець цілком відмовився від цього.
# — Я сьогодні це саме думав ||| — Йа думав цісе саме гадав сьми.
# Я прийшла до тебе, як сновида ||| ЙА прийшла ід тє, єк сновида.
# Точно як ті бідні італійці недавно ||| Адіо, адіо, єк тоті бідні італіяни оногди.
# Тоді Степан, плутаючись, почав пояснювати йому ||| Тоді Штефан, маневруючи, почав пояснювати йому.
# Ось чому я намагався попередити кровопролиття ||| Леда, аб сте я намагалися запобігти каліцтву.
# Мабуть, йому все-таки не сподобалося, що Андрій його так знамените розколов ||| Відав, йиму би ні вдалоси допитати, що Андрусик го йо знаменитий звивив.
# Але, ні, не може бути ||| Айби, не, не варти пробувати.
# Отак через смерть багатство роблять!" ||| Отак буває, коли вважають, що багатство робить людину!"
# — Кажуть, що він тут ||| — Говорєт, шо вин гир.
# Ті чи вам життя набридло ||| Цей снек вам вкличає.
# Навіщо, справді, його грошам пропадати ||| Нашьо, варе, го грошам гибіти.
# Ну, добре, що це жарт ||| Таким же біґмам, як ми, то бігме, шо цисе жерт.
# "Степан справді буває дуже злий ||| Стефану часто трапляється бути дуже пустим.
# Бажання — це мати думки ||| Хіть — цісе неня здохи, — сказав він, засміхнувшись.
# Він більше нічого не знає ||| Бірше нічого не знаї.
# А може, варто ворушити страх ||| Та варто пудивати, якщо відчуваєш годність.
# Дивуватися мені було більше нікуди ||| Зумів мині уже надоїлось.
# Він справді починає п'яний танок ||| Вин вора почне своє делец.
# Тепер мені іще цей клопіт ||| Тіпер міні теж має цес клопоція
# Як пізно він це зрозумів ||| Єк пізно він це зрозумів.
# А може й те ще.. ||| А й тут годен.
# Він хоче те все бачити ||| Вин хоче всьо це дізнатися.
# Все, що від тебе потрібне ||| Всьо, шо маєш та потрібне
# Потім жаль звогчив його очі ||| Витак жєль плив той річку.
# Він долізе-таки до свого порога ||| Вин долізе-прем ід свого порога.
# — Так саме, як тут ||| — Ий лаки, гає єк гир.
# Довелося йти обережно, надзвичайно пильнувати ||| Їти піксімістично, безпечно стерегтися
# Ось це і є межа ||| Леда звилася та вибухла хитрістю.
# А може, й усе життя ||| А й годен, капєц житє.
# Але ж не так відразу… ||| Якось не видразу йому доходило…
# Раптом все пішло несподівано швидко.. ||| Нараз усе пішло напрасно завзято.
# Високий, як батько, дебелий красень ||| Штивний, єк дьидик, гордо дебелий красунь.
# Наш слід до неї виведе ||| Нась піщик пойде і нас виве.
# Прислухайтесь: цікаво, як говорить народ ||| Послухайте: вері, єк балакає народ
# "Це дуже цікаво",— подумав Степан ||| "Цисе моц вере",— подмислав Штефан
# Це вона тільки змиє все ||| Цисе уна іно всьо зємив.
# Так от, це все неправда ||| Йо от, нічого не правда.
# Ніби він закам'янів, чи що ||| Отік вин закаменів, ци шо?
# Завтра вже може бути пізно… ||| Завтрішня вже пора.
# Але їсти все-таки  не міг ||| Не міг харчувати всьо-прем.
# Йому несила так піти геть ||| Йиму несила йо пошукати влаштовання.
# Яка любов, коли смерть довкола ||| Ика люба, якщо авс поруч.
# — Так, це той, що.. ||| — Йо, чуваке там, шошто..
# — Все це так зненацька.. ||| — Всьо цисе йо нагло, як каша розсиплась.
# Або загинути так, без бою ||| Однак підсилити його, без страху.
# І звідки він його знає ||| І вин знає собі.
# Так ніби їм зовсім байдуже ||| Йо вони не обертали уваги ні на що.
# Портрет виходив гарний, дуже подібний ||| Робота вийшла вдала, ретельно виконана.
# Може, ми ще колись побачимось ||| Годен, смо же колись зустрінемось.
# Але звідки вони все знають ||| А єйбо иків уже всє знают.
# "Вони до неї теж прийдуть ||| Уни ід ню також прийдуть.
# Отже, я вклинився через випадок ||| Отєж, вплутався я у краплину.
# Тепер треба гарно все попіднімати ||| Тідєр трєйно всьє попіднямати
# Видно, велика тривога в неї ||| Vикло, перший сигнал в Ньюйорку
# — Чи тут живуть дівчата.. ||| — Ци гир жиют челяґь... — сказала вона, махаючи руками.
# Якщо так, то до кінця!" ||| Наколов єс, та йду аж до кінця!
# Тільки дуже повільно плине час ||| Іно моло тихо пливе човен
# Ти думаєш, що я боягуз ||| Тай ти думаєш, шо я страшковий син?
# Як добре, що він босий ||| Єк шаєко, що він танцюється.
# Але той шлях йому заказаний ||| Той гостинець уже замовлений йому.
# (Нині я не так думаю!) ||| Ой не, не гадкую цього!
# Свій чи чужий цей натовп ||| Іноді свій цес, іноді ци чужий глітно.
# Людина є мразь, порох, ніщо ||| Людьина бують мразь, ковпіт, ничьо.
# Здається, вони перемовлялися між собою ||| Існуючи, ми перемовлялися один з одним.
# Я не такий, як вони ||| ЙМ не такий, єк уси.
# Тепер, звичайно, немає нічого похожого ||| Тіпер, ашош, не те ж саме.
# Я через тебе загубив окуляри ||| Юрішко загубив свій коляр.
# Це хтось, хто його знає ||| Цисе, котрий це знає, хьтось.
# Але ж ти чому там ||| "Тибо ж тячьо-сте генде"
# Вийшов тихо, щоб не розбудити ||| Увійшов мовчки, аби нікого не злякати.
# Батько мій італієць, мати слов'янка ||| Дьидик не суди, бо неня слов'янка.
# Як же так, без нічого ||| Єк же йо, бес нич!
# — Це майже як людина ||| — Цисе єкмай єк людьина, — сказав вже здарова лисина.
# — Звідкіля ти це взяла ||| — І вже ціська затянула.
# Н-да, тут треба бути пильним ||| Н-да, тре пабідати пильно.
# — О, я тебе розбудила.. ||| — АДЬІ, йе тє избужєла...
# Так, так, почалася пора світлячків ||| Йо, йо, спаласи мета світлячерів
# Тепер він один як палець ||| Тай вин тепер оден єк палець.
# Тепер скоріше вибратися б звідси ||| Тіпер маєш викупатися вици.
# А поки що життя важке ||| А заків житє тяжке.
# Я думаю, що він плакав ||| НЙ гадав, шо вон плакав.
# Диви, щось дуже знайома місцина ||| Ади, шош моц добре знайома місцина.
# — Що він там говорить ||| — Шо вин, генде зараз балакає?
# Скільки ще треба встигнути написати ||| Кілько треба вглізати, щоб написати.
# Тоді він почав боятися мене ||| Вин боєвси мене.
# А застрілився він зовсім недавно ||| І вин у той час в пил обточився.
# Але потім вони роззнайомились ближче ||| Обидва вони розійшлися, кожен у свій бік.
# Було ось так, як є ||| Було леда йиго, єк буюла.
# Аж тепер я це згадав ||| Аш тіпер вспомнівось эте.
# Я скажу йому, що трунар ||| ЙА відкажу йому, що треба.
# Аж ось де вони причаїлися ||| Уна леда де уни причаїлися.
# Так ось зараз вона буде ||| Йо бо ледви шо подієли вни будем.
# Тепер якраз іди собі спокійно ||| Тіпер іди собі спокійно.
# І це так само правильно ||| Та на, як його ріхтіґ.
# — Зараз я скажу йому ||| — Люба пам'ятатиме йому.
# Признаюсь аж тепер, що кинув ||| А я починаю зараз, шо верх.
# Це я вже від себе… ||| Цисе вже вид себе вивіжив.
# "А що, його день завтра?" ||| «А шо, го днина завтре?» — запитавси Іванчік.
# Це, видно, було йому цікаво ||| Бо насправді було йому видко йиму вере.
# Чи я осел, чи ти.. ||| Ци йа вислюк, ци тьи?
# Я відчула, що він тут ||| ЙА відчула, шо вин гиршав.
# — Ось тут ось внизу.. ||| — Леда гир леда понизше, понизше...
# Не може ж бути інакше ||| Не годно ж абиде інак.
# Не може — це ясно ||| Не годен — він ага.
# Авантюрист ти, як я бачу ||| Батяр тьи, а я виджу
# Те саме, що й ми ||| Тото акурат, шо й смо.
# Навряд чи це саме так ||| Цице навряд могли бути акуратними.
# Цікаво, що мені Загата скаже ||| Вере, шо мені Гакь скаже
# Тепер вони мерзнуть мені повсякчас ||| Тіпер у мене дуже холодно.
# Ти занадто упертий, але нічого.. ||| Тьи зарфки затлмени, айбо ничі.
# що ти там ще мазюкаєш!. ||| шо тьи гедне шось мазюкаєш!
# О, він це добре знав ||| АДЬИ, вин цисе єлоси знав.
# Вони говорили щось, аби говорити ||| Уни говорили, шош, би приказувати.
# Те "щось" ішло йому назустріч ||| Шош "шош" ішло йиму зістріт.
# А що ми без неї?.." ||| «А шо смо бес ню?..» — спитавси Іванчік.
# Але й те, що є!. ||| То й є!
# Він їде на інше полювання ||| Вин там на инчом гайті корови обгони.
# Сталося те, що давно назрівало ||| Відбулося те, що вже довгий час виникало.
# Проте, повагавшись трохи, вирішив-таки піти ||| Пречинь, з пошаною малечку, вирішив-таки пити.
# Лихо жде, але йти треба.. ||| Біда чекає, та йти треба.
# Та ні, не може бути ||| Та лиш не годен абиде.
# Завтра я від'їздю до Генуї ||| Угору йа від'їжджаю від Генуї
# — Я роблю це саме ||| — Я виготовляю цісе акурат.
# Це те, що буде потім ||| Ци воно має бути так?
# Цього ніколи не може бути ||| Сього ніколи не годен висікати.
# Вони ждуть полону, як щастя ||| Уни чублять полону, єк шосі.
# Я мушу тобі сказати, що мені тяжко говорити про любов ||| ЙА цес тобі кажу, шо мені теж важко говорити про любов.
# "Кажуть, Синиця заникує до неї ||| Говоріт, Синиця заникує ід ню.
# Отже, і він може померти ||| Отєж, і лиш він годен споч'іти.
# Але так було тільки зранку ||| Це його дивувало, бо Іванчик, бувало, ніколи не був легко втригувати досвіта.
# Ходи, проведу тебе до хати ||| Но піду до хати, проведу їду.
# — Тоді його треба зняти ||| — Тогди го тре прєстати.
# Це тут тато "Вісті" читають ||| Читають гір дєдя "Вісти".
# Адже колись він тут був.. ||| На колис гир буво.
# Чуже залізо й чужий вогонь ||| Зелізні чявуни та ватра-чужого.
# Запиши сам себе, ось тут-о.. ||| Запиши сам собі, злодійко, леда гири-адде.
# Але як до цього підійти ||| Ек ід сего підіти.
# Кожен думав, що то він ||| Жядний гадав сми, шо то він.
# Чому це так йому прирекли?. ||| Чий-сто це його приціли йому призначено?
# І він до цього покликаний ||| І вин ід сего муся.
# Що він мав від нього ||| Шо вин має вид нього.
# Однак більше не кажуть нічого ||| Прецінь краще мовчати.
# Як він змужнів, цей Роман!. ||| Єк він доторкнувся, ця Ромко!
# Це візник, що чекав його ||| Фирман, наредбата на която той чакаше
# "І це тому вони дивляться?. ||| "І цисе тимунь уни див'ютси?"
# Так, я пам'ятаю про це ||| Йо, йа це так добре пам'їтаю.
# Думав, що це від утоми ||| Шадав сми, шо цисе вид утоми.
# Мені стояти тут чи йти ||| Коти стоять біля гир, чекаючи.
# Це все-таки була велика приємність ||| Ціє всьо-прем коштувала найбірше до трьох доларів.
# Щось вона дуже йому боліла ||| Шош у нього більно йимо боліла
# Він перший кинув уламок скелі ||| Перший грегітий уламок.
# До нього треба тільки підійти ||| Ід до нього трошки та й підийди.
# — О, важко все починається… ||| — Ади, тяжко все зачинай...
# Суха ковила ще стояла міцно ||| Прошушена кійло шє стояла туго.
# Але щоб так лаялась жінка ||| Айбо абесте йо лаяла ізать клідіська.
# Це, напевно, було прибране ім'я ||| Цисе, відав, було мені прибране.
# Іди, не хочу тебе бачити ||| Иди, не втрачай часу.
# Відомо, що там усе є ||| Всі знають, що гендер-питання можуть бути важкими.
# Проте вони знають, що живуть ||| Уни вже знають, шо живуть.
# Мав говорити голова місцевого запілля ||| Мож прикозовати місцичного голя в хуті.
# І ось треба все залишити ||| І треба все обійти.
# Ось проходить понад очеретами навпростець ||| Леда траф'єїтси напопереки серед очеретами.
# Чому я зобов'язаний його жаліти ||| Що я зобов'язаний їй побажати
# Звідкіля тільки все те береться ||| Відків іно всьо тото береться - Відків іно всяко те терпиться.
# Але зовсім- ніби й правильно ||| Але хәд- ютәш к хәлүур
# Чи сниться, чи справді діється?. ||| Ци снитци, ци варе потраф'їтиси?
# Так що ми тебе охороняємо.. ||| Йо шо ми охороняємо.
# Але це ще не все ||| Eхтифф кручвє яцше пїцть.
# Але він прийшов не так, як звичайно ходить вечір ||| Айбо він прийшов не йому, як вечорі ходятимуть.
# Все, що заважає його відчувати, чуже й байдуже мені ||| Все, що заважає йому відчувати, здавалось й байдужно мине.
# Просто я хочу, щоб цей місяць тут кипіла робота ||| Просто я занурююсь, абесте цеї ночі під ковдру праці.
# Чого це вони так, неначе злодії, роблять своє діло ||| Що цісе уні йо, отак злоґійнє, роб'є своє інтерес.
# Яка радість не побачити завтра те, що бачиш сьогодні ||| Не варто надіятися побачити завтра те, що бачиш сьогодні.
# Доки я можу чекати ||| Доків я можу пардонувати.
# Ми це все бачили.. ||| Смо цисе всьо видили.
# — Це зовсім інше ||| — Цисе прем гадав, а шо цисе прем казав.
# О, ми ще подивимось ||| АДЬИ, адімо ж подивимось.
# "Чому ж "так собі" ||| Чьо-сте ж "йо собі"?
# Зараз я тебе зловлю.. ||| Леда йа тє зловлю, видиш, шо йду на лови до ставка в ліску.
# Вони "йдуть у бій"!? ||| Уни "идут у вою"!?
# Ой, як свербить тім'я!. ||| Ий, єк вже свербить тім'я!
# Мабуть, таки вже пізно ||| Прі пиздо.
# Ще нічого не видно!" ||| Шо ни видко!
# — Чому це раптом ||| — Та Што вы цей нараз?
# Аж шкода було дивитися ||| Аш жєль було обзерати, вельми усилед було безплідно.
# якщо той листочок осиковий ||| наколи тамтой листочок трепетовий
# "Так, ми ще подивимось!" ||| "Йо, шо ж тут буде!"
# Я все точно підрахував ||| ЙА цілком спозвав зракунок.
# Все це сталося блискавично ||| Всьо цисе трапилося невдовзі.
# І зараз те саме ||| І таще се акурат.
# Вони вже зовсім близько ||| Уни уже дуже близько.
# Чорт знає, що твориться ||| Мольфар знаї, що діється.
# І грає її дівчина ||| Играють ї чорса.
# Запиши все-таки моє прізвище ||| Запиши все-прем моє прийменне.
# Я вдав, що сплю ||| ЙА вдав, шо сп'ю, бо вже пізно.
# Я удавала, що сплю ||| ЙА удавала, шо сп'ю.
# Усе видить тільки Бог-Соварог ||| І "капусть дивиться Біг-Соварог".
# Адже ще чотири літа ||| Прецінь шє штири літа, шесть літами.
# Це ж його книги ||| Цисе ж го документик
# А ми тут що ||| А шо було?
# І я мушу йти ||| І мушу ити.
# Що там діється, Прісю ||| Що таємницею зостається, Прісю
# Ой час і пора.. ||| Ий чєс і мент жили мовчки.
# Це вийшло досить зухвало ||| Цисе провалилося марно
# Тоді я зважився відкрити ||| Та й тоді я зважився розділити.
# Щось він там господарював.. ||| В шош час господарював.
# Вони ще досить стримані ||| Уни шє вільні.
# Чи справді вже пізно?! ||| Це вже пізно!
# Я розумію його тепер.. ||| Й я це тепер розумію.
# Те саме й там ||| Toto is just a kid
# Щось між собою побубоніли.. ||| Шош мижи собов побубоніли.
# — Це до мене ||| — Цисе ід від мене.
# Тепер ходи, щось покажу ||| Шош тіпер буду ходить, таки покажу.
# Зараз ми щось придумаєм ||| Леда, давай щось вигадаємось
# А мабуть, що так!. ||| А воно й правда!
# Я гадаю, що Нерона ||| I гляджу, што Нерона.
# Усе йде до цього ||| Кацо йде ід сего.
# Тільки мукає, як бугай ||| Ін перебирає, як колосок
# Він стоїть, як вовк ||| Вин стоїть, єк флуд.
# Тоже мені нація зачухана ||| Жінка сховалася в кущах.
# — Не може бути ||| — Ади — не годен.
# Вам це не личить.. ||| Вам цисе не клише.
# Що ти мені говориш ||| Шо міні ти говориш
# он те, що впало ||| аді й тепер побіг за небом у заліт, чи му впало на голову.
# — Ти що, злякався ||| — Ішо ті, изжьих сі.
# І все-таки вони кричать ||| І стрім уні кричать
# Яка тут її роль ||| Ика гир зі грою
# Перекинули через плечі рушниці ||| Покотили куплю кобилі в лоберок.
# — Хитрий ти чоловік ||| — Штудерний тьи хлопив.
# — Іди до мене ||| — Иди за мною.
# Вони можуть зараз прийти ||| Уни можуть ледве з'їсти.
# Журба пильно розглядав обличчя ||| Гриза приглядалась до тварини.
# Стій, я зараз присвічу ||| Гірко, це місце неосяжне
# Ось чому така смерть… ||| Леда чудовищно вимоталася…
# Що я там загубив?. ||| Що ти шукаєш по дорозі, де втратив своє?
# Звідки вони тут взялися ||| Іків уни гир аплікався.
# Це ж той диявол.. ||| Юда, куда ж там цисе.
# Так я до вас.. ||| Йо йа іду туда.
# Потім зайдете до мене ||| Витак зайдете ід мене, й не знайдете вас.
# Він заходить до Петрунів ||| Він приходить до нас до Петрунів.
# Через це кінчаю писати ||| Ці зрозуміло кінчаю шрайбати.
# Ми все-таки вирішили подрімати ||| Ми усім-усім зачом-таки подрімувати.
# Треба ж його мати ||| Тре ж нянюй його.
# Тільки ти трохи почекай.. ||| Іно тьи малецько почекаю.
# Але мені було байдуже ||| Мині байдуже.
# Треба буде завтра щось ||| Тро буде завтра щось
# Але що це значить?. ||| А шо воно таке?
# Від цього стає легше ||| Вигляд цього стає краще.
# Час іти на побачення ||| Ческий идет к реке.
# Звідси почнеться новий наступ ||| A новый офензива начаться.
# Вірш адресую до тебе ||| Ащкш оыхрч зввчріцз яйир фхщ єюатор.
# "Та не може бути!!" ||| Та не годен залишитися!
# Це ти замість Миколи.. ||| Цісь тьи наміж Миколи, шоби він збігав кількі світи через замети.
# Від цього стало страшно.. ||| Вид сего стало давати пуду.
# Ось вона, козача кров ||| Леда таразу, ограна сонди
# Через годину я від'їду ||| В час прибуття я від'їду.
# Тут я можу танцювати ||| Ми моратимемо танцювати.
# Але все те дрібниці ||| Айбо всьо наипристрашнійчо дрібниці.
# Бакун, так це ти? ||| Бакун, яке тьи чисе?
# Я її міцно потиснув ||| ЙА ї туго потиснув
# — Я пити хочу ||| — ЙА танцюю весело.
# Як усе це опошлили.. ||| Єк капєц цисе опошлили.
# Це — її душа ||| Цисе — ї содухи.
# Очі дивилися трішки знизу ||| Сліпаки глядали крішку з долини.
# — Відаю, що далі ||| — Свідім, шо далеко.
# Чи догнав її Заєць ||| Ци догнав ї Заїца
# Це — через Чебрець ||| Цисе — чіріз Чєбрик!
# Чи то я дитина?".. ||| Ци то йа бахурчік?".
# Цікаво, як його звати ||| Та вере, єк го звати
# Голова все більше наморочилась.. ||| Гола всьо бірше наморочилась, а горілка й закуска порожніміють.
# Очевидно, це тільки слова ||| Видко, цісе іно чива
# Чи живий той хлопчик ||| Там живий цей хлопчіш.
# Це я напевне знаю ||| Знаю цісе йа бізівно.
# Боже, якби йому рушниця ||| Боже, коби йими крила.
# Але тут і господар ||| Айбо була ґазда.
# Для чого вона тут ||| Нащадок з тими самими гирками скоїв нещастя.
# Треба писати, коли почав ||| Трохи шість, як крапля
# Це триває п'ятнадцять-двадцять хвилин ||| Цисе триває двадцять-дві хвилини.
# Я тебе дуже, дуже.. ||| ЙА шо, шо.
# Я зайшов до хати ||| ЙА зайшов до хати.
# Я все міг приховати ||| ЙА міг взагалі спуститися.
# Може, хата ця неплідна ||| Годи, осєдок ся безплідний.
# Ось тільки трішки полеже.. ||| Леда іно полеже, єк заснула.
# Йому йти повз млин ||| Йиму іти зовидіти млин
# — Як це "тут" ||| — Єк цисе "гир"
# Привіт йому від мене ||| Вид мене йимець.
# Микола ж мій там ||| Мирославо ж моє серце
# Андрій ще більше захвилювався ||| Андрусик шораз, то бірше все гачіла захвилювався.
# Зрештою все може бути" ||| Наостанок всім добре підходить.
# О, тут вони господарі ||| Ади, гир уни має свого господарі.
# Якщо справді вона повернулась ||| І наколи уна обернулась.
# Охорона он, бачите, яка ||| Сторожа, люде, бачите, іка.
# Це була її мати ||| Цисе була ї неня.
# Він сильний і сміливий ||| Вин достойний і відважний.
# Чи як ти думаєш ||| Ци єк то має бути?
# Он вони везуть її… ||| Аді уни були переміщені.
# Але я хочу квіток ||| Ах таємнича краса цього квітучого бутону
# Мені подобається твій Богдан ||| Мій Богданочку, викладайся.
# А чоловік її злодій ||| А хлоп ї грабивник, так задрижєв, єк лист вид вітру на трепеті.
# Але ти подобаєшся мені ||| Ти мені подобаєшся.
# — Не може бути" ||| — Нехай не гідний залишиться.
# А далеко ще йти ||| А вуккі лєсно працюе
# Здається, я трохи намок!" ||| "Отєк, йа намокла тут!"
# Це прийшла остання ніч ||| Цисе прійшла довга ніч.
# Йому там добре буде ||| Йиму генду буде.
# Але вона не прийшла ||| Айбо вона ні не прийшла.
# Може, це мені наснилось ||| Годен, цисе міжно дойде.
# Але це якраз і було те, що треба ||| Цісне було і якрас, як тото, шо тре.
# Я тебе підкую трохи ||| Й тє підкую маленько.
# Казав, що життя погане ||| Казав, шо житє без мене ни годен.
# Та що я, справді ||| Та шо йа, варе.
# "Як вони не бачать ||| Єк уни не підходить.
# Але й не так ||| Айбо йо, небискум просто.
# Приготуй мені прощення гріхів ||| Готуй тіні гріхів.
# Мальва відповідає: "Це я ||| Мальва відповідає: "Це я".
# Зараз ми його подратуємо ||| Леда го потуцнемо.
# Потім рушив до хати ||| А витак рушив ід хати.
# Все тяжче йому було ||| Всьо йиму було тєшшє.
# Степан запропонував йому цигарки ||| Штефан пропонував йому папіроси.
# Чи вам сьогодні легше ||| Ци вам, може, сьогодні краще?
# Все це зробила баба ||| Всьо цисе створила.
# Колись, до революції, здорово жили тут наші люди ||| Колис, під час революції, наші люди добре показали свою силу.
# Так ти будеш говорити ||| Йо мусиш викидати.
# Тепер тут було легше ||| Зараз гир зробити було простіше.
# Червоні незабаром будуть тут ||| Червоні лінії будуть гирше.
# Я теж недавно прийшла ||| ЙА теж прійшла оногди.
# Обід готовий, горілка є ||| Полуденок готовий, горівка бують.
# Там, звідки його вигнано ||| Генде, іків вигнано.
# Ніби вчора почав і.. ||| Отік учів говорити.
# Люди пізнаються через довір'я ||| Люде пизнаются чіріз довірє.
# — Чи знає "він" ||| — Ци знаї "вин"
# Ще одна людська ілюзія ||| Шє нездійснене мрією.
# Ти дуже мені пособив ||| Місив чи ліпив, тьи моц мині пособив.
# Це — те саме ||| Цисе та акуратіться.
# Вони всю рибу з'їдять ||| Уни всу рибу з'їдали.
# Скільки йому ще битись ||| Кілько шепотіла йиму битись.
# Що там йому розганятися ||| Шо генде йиму збігатися.
# Але так тільки здавалось ||| Ідо йино знявалось.
# Ми б тут ого ||| Мчцч о ашм ушзшлрзол
# Спалося спокійніше, ніж вчора ||| Спалося ніжніше, раніше вчора.
# звичайно, якщо вони непримиренні ||| Ашош, наколи уни до кінця не встигнуть упоратися.
# Отож іде до діда ||| Отєж побіжить за дідoм, єк котюжка, нам, шо він має робити.
# Та це не так ||| Та й цисе не йо.
# Вони ввійшли до хати ||| Уни зайшли до хати.
# Так звик думати Андрій ||| Йо звик бачити Андрусика
# Усім зась до мене ||| Усім засій, хлопи, мене не дивіться.
# Ти давно цього шукаєш ||| Тем давно ищешь это.
# І ось тут раптом його душа стала цапки ||| Ік в суці гир нараз тоді стала водуха цапки.
# Не так це робиться ||| Не йо зісце робиться.
# Хто може сказати, чому саме я лишилась жива ||| Хто здатен розмовляти, що саме я залишилася жива.
# Чи це було вчора ||| Ци тутечькі було учєра
# Але Горобенко прекрасно знає ||| Aйбо Горобенко добре знаї
# — Але що це ||| — Або що це
# Хто це так стрельнув ||| Хьте кху стрйелон?
# Як, звідки вона взялась ||| Єк, ик, иків вона взялася
# Мабуть, порох давно висипався ||| Відав, так ковпіт висипався давніш зараз.
# І як-от вона тужить.. ||| Єк-от уна тужить.
# Адже ж вона була.. ||| Прецінь ж уна була красномовна.
# ходи роті до мене ||| рукі роті ід мене
# Ще не час, однак ||| Не то шо не віриш, пріж.
# Ну, це так треба!. ||| Ну, вер' йо тре!
# Я: Є щось негайне ||| Йа, справді: негайне буйт шось.
# Але треба вирвати в ||| Чом треба було йому вірити?
# Так, вони дуже боялись.. ||| Йой, уни так пуцно на мнє напосів..
# Зараз ти це побачиш ||| Той двір нашій окаламений
# Та що там світ ||| Та шо сьвіт генде.
# Він цілими днями думав ||| Сми він часто думал цілими уніжди.
# Кара прийде, але згодом ||| Правда прийде, або ділитися.
# Як не знати Явтушка ||| Єк не кібзувати Явтушка.
# Треба конче зробити щось ||| Трохи роботи, заробити, шош.
# Але трішки не там ||| Кажі кришечка.
# Ось як є, сам ||| Леда єк буют, самше.
# — Давно вони тут ||| — Давніше уни гирже.
# Як зараз пам'ятаю, "Приму" ||| Леда поміняла.
# — Я хочу померти ||| — ЙА пони споч'іти.
# — Не може бути ||| — На, не спокутниками.
# "Ось так виглядає мерзость!" ||| Леда як зимова морозький біда!
# Там має бути гать ||| Гуляй бандурою, не дивись на людей.
# Вони скоро його догнали ||| Уни швидко його догнали.
# Сьогодні з’їв, завтра голодний ||| Сьогодні поїм, завтра голодний.
# (Чи то Федір Журба?..) ||| Ци Федько то заздрів, то осердивси?
# Дивлюся: що він робить ||| Див'юси: шо він там робить.
# Цікаво, як ці повернуться ||| Верне.
# — О, рівно п'ять ||| — Аді, дознака п'єть.
# Я цього майже чекав ||| ЙА тут довго чекав.
# Швиденько, як злодій, пішов ||| Начєс, як грабивник, пішов.
# Ні, не може бути ||| Не годен примиритися.
# Але все те марно ||| Всьо хіба марно, бо ця швидше за все буде видно.
# Цікаво, що він одписує?. ||| "Та шо, як в Талліні на Леоніда Тарновського завважив?"
# Чи, може, що сталось ||| Ци, шо сталося?
# О, це велика зміна ||| АДИ, цисе зміна в бірьшї.
# Заіснував якийсь новий порядок ||| Заіснував йикий пильяний рад
# Це було давно колись ||| Цисе колись було завдавно
# Як це все розшифрувати ||| Єк верифікувати всьо.
# Це я знаю точно ||| Цисе, ШО знає йа адійо.
# Але вони не йдуть..." ||| Айбо шо ж не идут...
# — Навіщо так багато ||| — Насційо йо велико.
# "Іди ти до біса!" ||| "Идь-и-и боса-а-а!" — вигукнув Іванко лютим голосом.
# Але нічого не сталося ||| Та й що з того, усе ж не потрапилось.
# Так ніби його забули ||| Йо, криниця же забулася.
# — "Звідки мені знати ||| - "Иків мині кібзувати".
# Гадаю собі: чи.попросить він ||| Собі попроси вин.
# — Як там живуть ||| — Єк де вони живуть?
# Хоч нехай там що ||| Я хочу натиснути ту кнопку.
# Григорій прагнув скоріше додому ||| Hanna хотіла краще вивчати французьку мову.
# Ти мені краще скажи.. ||| Тай мині ліпше скажи.
# — О-о, це прекрасно ||| — АДЬІ-адьі, цисе файно
# — Як там наші?. ||| — Єк генде нашинскі? — «Єк ни питавси?».
# Біда, нещастя спостигли його!"… ||| "Біда його спіткала, каже!"
# що ж йому сказати? ||| що ж їй сказати?
# Як я тебе згадую ||| Єк йа тє зарпаду.
# Ми ще трохи поговоримо.. ||| Шо маємо маленько поговорити.
# Що ж це я!. ||| Йа їо чос!
# — Що там, тату ||| — Чим би тут, брате?
# — Лікар добрий чоловік ||| — Доктор добре вилікував.
# Я кажу про неї. ||| Кол я ту про ню.
# Гадаю, далеко не кожен ||| Майдалі гадку, не жиди гадказю.
# Та не може бути ||| Та не годна ат да пустити.
# Він її звів трохи ||| Вин зробить маленьку штуку.
# — А може, назад ||| — А годен, назад
# Тільки я ще подумаю ||| Іншо йа подумаю.
# Скрізь я вбачав його ||| Ізнутрі він побачив її.
# Я вже трохи навчений ||| ЙА вже маленький укий.
# — "Так це він ||| - "Йо вин цисе."
# Вибачайте, але що є.. ||| Вибачайте, або що бують.
# Щоб зіпертись на неї ||| Зіпертись на стірку
# Що чоловікові ще треба.. ||| Шо чоловіку не має треба.
# Не розстрілюють поки що ||| Не розбивайте кров на двері.
# Роблю я все машинально ||| Робив усе машинально.
# Тепер той будинок рудий ||| Тіпер той хижає рудійша.
# Андрій нічого не думав ||| Андрусик не відгадав жодного слова.
# Він наказав рушати додому ||| Вин вирішив втекти.
# Але тут була людина ||| Айбо буки єнген людьина
# Він не знає, він нічого не може сказати ||| Вин не годен нічого зговорити.
# "Що ж тут вибирати?" ||| "Шо ж гей вибирати?"
# Невже через мій від’їзд ||| Чіріз чи вид’їзд ти невже.
# Але тільки я засинав, кінь приходив до мене ||| Айбо іно заснув, то конє прийшов від мене.
# Я його, мабуть, теж.. ||| ЙА, відав, теж зрозумів.
# Потім прийшла заплакана Катерина.. ||| Прийшла заплакана Катеринка до нас..
# Чи може таке бути ||| Ци годен таке абиде.
# Ніби якийсь злий дух намірявся на його спокій ||| Отік пустий дух на го покі намірявся.
# Чи це від божевілля ||| Ци цисе вид відлюдня
# Так ти це підтвердиш.. ||| Йо цисити підтвердиш.
# Була ще тільки восьма ||| Шє іно останя була
# Я так і думав!" ||| "Йо, йой думав смі!"
# Я її напам'ять знаю ||| Їй я це запам’єтаю.
# Я-а, що мені вчиниш ||| Йа-а, шо мі вчиниш.
# Якось так він висловлювався ||| Йос вин висловлювався.
# А може, в неї така відраза до нього ||| А годен, в ню така пізьма іде з нього.
# А поки є куток.. ||| А заків буют оседок.
# Я звертаюсь до тебе ||| Й я звертаюсь до тє.
# І це точнісінько так ||| І заснилося йому.
# — Ні, але все-таки ||| — Ні, то не так.
# Так я собі міркую ||| Шо йої, йой.
# Там наші найкращі солонці ||| Гэтыя падускі нашыя самыя прыгожыя.
# Геть набік її всю ||| Гет наборгали всі.
# Дуже цікаво мені послухати ||| Мині вере хоче послухати.
# Вона боязко поглядала навкруги ||| Уна бійно поглядала наоколо, вона всьо знала.
# Це якраз і добре ||| Це - карта і писаниця
# — Може, там похорон ||| — Годен, генде опровідуй.
# Це все не новина ||| Не побачив я все.
# Не може бути, щоб мене випадково так обплутало.. ||| Не гожусь дома, аби мене невчасно відвідинало.
# Ой, як нас багато ||| Ий, єк великий у нас.
# Назад так само наввипередки ||| Назад йо лише впередки.
# Це переддвер'я в "ніщо" ||| Цисе переддвер'я в "ничьо" отворилиси двері.
# Він, видно, був уже п'яний, очі мав червоні ||| Вин, видко, вже був останній, сліпаки мав червоні.
# Потім трішки зніяковіли: ждуть ||| Кришка зніяковіла: чікаємо.
# Мені треба багато подумати ||| Мині трохи вигодилоси подумати.
# Це справжня його Катерина ||| Катерінка справжня й го.
# Іспит завтра, і він його зовсім не боїться ||| Еґзамент неважливо, бо він проходить без проблем.
# Говорить про те, що Андрій молодий і йому треба жити, працювати, любити.. ||| Балакає про тото, шо Андрусик книгу і йому тре жити, працювати, навідувати.
# — Так, це я.. ||| Йо, цисе йа.. - Шо йой, йа.
# Там уже щось сталося ||| Генде вже шош пало.
# Інші вбрання, інший зміст.. ||| Инчи ні, бо убив би зміст.
# Це ж ти так.. ||| Цисе ж тьи йє.
# Це все давні світлини ||| Мылька всё дрэўнія выявы.
# Ех ти, біда яка ||| Єх тить, смажа іка.
# Від неї годі одчепитись ||| Вид той ню гляба не хотів одчепитись.
# Ой, як її мордовано! ||| Ий, єк ї мордовано! - Ий, єк це прідещ!
# Очі йому підозріло якось ||| Сліпаки йиму підозріло йкос поглядали.
# Я ніби переживаю все ||| Я оцік переживаю всё.
# Якісь чари, чи що?" ||| Якісь чєрі, ци шо?
# Це мені тепер непотрібне ||| Цисе хоча б тепер зайва
# Він знає, хто стріляв… ||| Вин знає, кто стріляв...
# — Тут повітря інше ||| — Гир люфт ґадзе
# Ніде мені так гарно не спалось, як тут… ||| Міні нікому ни допомагало, єк та єдина гірше мені спав.
# Як вони міцно сплять ||| Єк уни не можуть спати.
# І ми жили добре.. ||| Із жерела кипівської водимищі єлоси текли.
# Ідуть в один двір ||| Идет в оден гофа.
# — Чому не знати ||| — Чьо-сте не кібзувати, ни в шкарпетках та не в чибрах.
# "Звідки вони все знають ||| "Іків уни всьо знають" — сказав поважно Малиш.
# Вони тепер ідуть удвох.. ||| Уни двоє пішли удвох.
# Але лихо переважно роз'єднує ||| Усе ламається в хаті, як біда вікно.
# Все життя він думав, що його сили невичерпні ||| Всьо житє вин вважав собі, що його сили невичерпні.
# Богдан пропустив його вільно ||| Богданчик пропустив Його з великим спокоєм.
# Ось і хата його ||| Леда і осєдочьок го убрав.
# не так мене видно" ||| не то мене зрозуміло.
# що я чесна людина ||| Шо йо, чесна людьина.
# Якесь пристановисько треба мати ||| Пристановитисько таємничий.
# Вона мені як сестра ||| Уна була мині, єк сестра.
# Як же не знати ||| Єк же не помагати.
# Що їм треба тут?. ||| Що їм потрібно з тією гирею?
# Отже, тепер все знаєш.. ||| Отжеж, тепер усе вже знаєш...
# Поки що гупали гармати ||| Пустіли вогні і відкривали гармати.
# Мені все тепер далеке, про що говорить він ||| Міні вже так далеко, що замовкло мовчання він.
# Йому раптом забракло повітря ||| Йиму нараз забрався людд.
# Тепер він доб’ється додому ||| Тіпер вин доб’ється ід'хаті із дозволу пана.
# Ще щось там робили.. ||| Шош лиш гинде робили.
# Якось він ледве стримався ||| Екош тис дебя стримався.
# Повна безпорадність злякала його ||| Набитіська безпорадність належить го.
# Звідкіля вони все знають ||| Він всьо знає.
# Богдан пристав до думки ||| Богданчик пристав зійшов до загори.
# А додому ще далеко ||| І в'їздили шє майдалі.
# Але як те зробити ||| Айбо воно маха було зробити.
# Цього щось більше нервувало ||| Сего, то гірше ставало нервувати.
# Кажуть, що вони парашутистки?. ||| Розповідаєть, шо уні парашутистки?.
# І я мав щастя.. ||| І йа мав таке шєстє.
# Як і "вони" йдуть.. ||| Єк і "уни" підуть.
# Я тобі наказую: йди ось через цей потік ||| ЙА тобі заповідую: іди геть тут і залиш цю мить на завтра.
# Але від чого далеко ||| Що за штука?
# Що я хотіла сказати ||| Шо я навіть хотіла заговорити.
# Але Він мав усе, таки до кого гукати.. ||| Вин вже знає, з ким гукати.
# Дійсно, як кара Божа ||| Варе, єк так тобі Божа воля.
# Це його законне місце ||| Цисе си купие пляц.
# Він зовсім занехаяв її ||| Вин прем горділицею.
# До мене руку тягне ||| Ід мене ногу крає.
# Ну, як там "мова" ||| Ну, бай генде.
# А може, й смерть ||| А годен, й авс - Ни годен вигадати, що вона прибагне.
# То ми й жили-колись ||| То смо й жерела-колис люди настоювали та й пили воду.
# Але його нікуди сховати ||| Айбо го нікуда не відкрити
# Його легко було жаліти ||| Лекше було жєлувати.
# І так яка робота… ||| І йо ика виплакала.
# Аж ось щось задудніло ||| Та ледви шо задудніло.
# Тепер уже все добре ||| Тіпер уже все злосьî
# І погляд холодний, гордий ||| І морозний, розумний.
# Так, це його дім.. ||| Йо, цисе го дім.. - Йой, цисе го дім!
# Що, не так, Повсюдо ||| Шо, йой не, Повсюдо
# Все-таки вона не йшла ||| Всьо-прем не йшла
# Якби трішечки більше світла ||| Коби більш світла бажав.
# Так, це була свобода ||| Йо, було цисе слобідно.
# Добре, як хто добудеться ||| Єлоси, єк хьто дастоєтси.
# — Поки що таємниця ||| — Заків ші таємниця.
# Але от саме цього й не може бути ||| "А щоб він вже від этого й не був годен ні відпущать."
# Отже, дійшли-таки до Діброви ||| Отєж, дійшли-прем ід Діброви.
# І готувався до неї ||| Я майструвався з головою в книгах.
# Хто вони, ці люди ||| Уни якой він, а ни люде
# Так йому й треба ||| Йо йшла йиму до тре.
# Він завжди ненавидів похмілля ||| Вин вражаи ненавидів похмилка.
# Іди лишень сідлай коні ||| Піди наколи та виїдь с.idle
# Тепер я його розчарував ||| Тепер я розчарувався
# що я буду говорить?" ||| "шо ж буду балакати?"
# Це не його діло ||| Цисе не є його зацікавленням
# Саме о цій порі вона може повертатися додому ||| Згодар, та не треба годен корнєтися ід'хаті, бо можна нарватися на лихо.
# А що я роблю ||| А шо я тут роблю?
# Але я вирішив піти ||| Аби йа вирішив пити.
# А може, навмисне пробалакався ||| А шкода, що не вдалося пробігати - аж годі було спробувати.
# Все, як ти сказав ||| Всьо, єк тьи сказав.
# Потім все якось змінилося ||| Витак всьо нібито змінилося.
# Я-м багато слухався тебе.. ||| ЙА-м велико слухати.
# От, зовсім молодий юнак ||| От, прем книзяр хлопец.
# — Це той, що.. ||| — Цисе там, шо...
# Як він перебивається, бідолаха ||| Єк вин дліто ламається, сарака.
# Ось вони їдуть Гусинкою ||| Леда уні їхають Гусинкою.
# Ой мамочко, я боюся!.." ||| "Iйо, мамочко, я вже боюсь!.."
# Його весь світ знає ||| Го весь сьвіт знаїть.
# — Так тільки здається ||| — Йо іно отєкого.
# Вони світять, але сліплять ||| Світ світить, чи сліпить.
# Так, він знає Зайця ||| Йо, вин знаї Зайця.
# Як творив Бог світ.. ||| Єк творив Біг сьвіт.
# Але всюди панувала тиша ||| Айбо він був паном, покі не відпустив її.
# Не знає Андрій, чому, але йому так здавалося ||| Не знаї Андрусика, шо-сте, або йому йо здавалося.
# (павза) Мені треба поспішати.. ||| Та мині тре пилуватисі.
# Я рушив до нього ||| На дорозі та вродився.
# Це лист від Миколи.. ||| Цим письмом Микола написав.
# Але що буде далі ||| Або шо там станеться.
# — Чому так пізно ||| — Чьо се пизно.
# Дупло або ще щось ||| Альбо дупло шє шош.
# — Що він свиня ||| — Шо вин сьоня
# — Там піч холодна ||| — Генде п'єць студену.
# Це був страшний удар ||| Цисе була сварливою шимпанзею
# Я так і думав, що ти десь тут ||| ЙА йо думав, шо тьи десь гирше.
# Я подумав: "А може, це означає щось більше ||| ЙА подумав: "А шош цісе означає шош бірше"
# — Я дуже брудний ||| — Айо моц лепкий.
# Та що тут балакати.. ||| Та шо гей говоркала..
# Так, значить, ти є?! ||| "Йо, значить, ци б'ют?!"
# Вона метушлива, як повія ||| Уна була метушлива, єк гониця.
# Так, так, саме Вишневі ||| Йо, йо, видивний Вишневі
# Тільки як те зробити ||| І він тото може зробити.
# Ось юнак, років 18-ти ||| Вони говорили, що хлопець грає на скрипці так, що не можна налюбуватися.
# О, тоді ще подивимось ||| АДИ, тоді побачимось.
# А може, мені привиджувалось ||| А годен, міні мріялося.
# Ні, що я кажу ||| Ні, шо йа такі.
# Але як я мріяла ||| Шоби єк йа мріяла.
# Вона вже давно тут ||| Уна вже давніше гирішку.
# Тоді міцно нацупив її ||| Тоді туга наростала все більше.
# Тоді це не тут…" ||| "Даключч изис не бур..."
# Що таке "час іде"? ||| Шо таке "чєс йде"?
# Це він так спав ||| Йак це син мав.
# А гляди, що так ||| А дивикоси, шо йої.
# Чоловік пригортається до мене ||| Хлоп приблизився до мене.
# Вони щось говорять притишено.. ||| Уни шош говорєт тихо...
# Я бачу щось інше.. ||| ЙА може, шош инче бачу.
# — Клопіт мені великий… ||| — Бермудський гулляр…
# Чи, може, ти сам ||| Ци, годен, се.
# — Так, так є ||| — Йо, йо буют!
# Але їхати, проте, треба ||| Айбо їхати, прецінь, треба
# Вам їсти чи пити ||| Будьте ласкаві, харчуйте ци глядайте.
# Так, різні вони люди ||| Йо, ріжні люди уни
# Нічого не може вдіяти ||| Ніч ни годна вчинити.
# Ну, це ще здорово.. ||| Ну, йоув'єт шє файно.
# Тепер — це тюрма ||| Цисе фурдиґа тіпер.
# — Чи тільки війна ||| — Это во войне
# Легко сказати — іди ||| Легше говорити — іди
# Це був великий пройдисвіт ||| Цисе був полум'яним куштаном
# Що це все значить? ||| Шо це відсе значить?
# — Ой, ти сьогодні.. ||| — Ий, тьи таки сёндне..
# Чорт його не візьме ||| Той мольфар?
# Тільки я так думаю, що ти не приїдеш ||| Іно, не те що приїдеш, а й навіть не гадкую.
# Тільки уявити її здивування ||| Іно уявив, як її здивувано.
# Раптом — що це? ||| Нараз — шо цисе? - Нараз – шо цисе?
# — Ось тут, сюди ||| — Ледо, гир стрибне.
# Як же це так ||| Єк же цисе йо!
# Щось там вони поговорили ||| Шош генде уни поговорили.
# Про що тут говорити ||| Про шо гир приказували
# Ні, вперед, до життя ||| "Ні, вперід, ідем життям."
# Точнісінько, як ти оце ||| Снісько, єк у тебе такі.
# Я вийшов на подвір'я ||| ЙА вже на подвірічку завітав.
# Ось ти зараз почуєш…" ||| "Леда тьи леда почуєш…»
# Коли тебе чекати назад ||| Коли ти туда допижджаєш?
# Може, потім якось розвидниться ||| Годец, витак йькос розвидьнитьси.
# Він пройшов дуже багато ||| Велика мок провитрює його.
# Він думав про смерть ||| Він говорив сам про себе.
# Ти не боїшся нічого ||| Тьи мійти, бо си зні для других.
# Проте, зрештою, яка різниця ||| Прецінь, врешті-решт, ніякої ріжниці.
# Мати похопилась: пора обідати ||| Нянька захопилась: поліцейський хоче ревнощівати.
# Ти боїшся його глузів ||| Тьуземкі грікошим го глузів.
# Мені до того байдуже ||| Мині ід так лежать.
# Все так страшно, братіку ||| "Все йо важко, братчику"
# Тепер я вже відаю ||| Тепер я уже почуваюся
# — То як так ||| — Та єк йо
# Я хочу бути журналістом ||| Я хочу стати журналістом.
# — Діти ще тут ||| — Ґіри шє тім
# — Ой, як страшно ||| — Ий, ай шкода
# — Дощі там бувають ||| — Дощі гойдають гіллям.
# То нехай дід колись ||| То най ґідо буде.
# — Радянська влада не може йти проти закону ||| Совєцький урід не вартий виходити проти закону.
# Дружина тільки плаче — нічого не може сказати ||| Жінка іно плаче — нич не годен говорити.
# Чернишов тепер його товариш ||| Чернишов теперь мой друг
# Звідки ця несподівана криза ||| Ся несподівана тугота иків.
# Але це — якщо.. ||| Айбо шо ж?
# Ще зачекаю якийсь час ||| Зачекаю йикийс шє жду.
# Це видно так чітко-чітко ||| Цісе яскраво йо барвисто-барвисто
# Ще вчора він мав ліки від цього незатишку ||| Вид учора вони мають ліки від цього незатишку.
# Незабаром стежка пішла вниз ||| Делінь плай дошла вид полину.
# Це ще й добре місце він мав, не один, мабуть, йому заздрив ||| Сісе, якщо якогось дня він мав можливість одягнути не одне вбрання, відчув, що заздривала.
# Я його сьогодні бачив ||| ЙА сьогодні його побачив.
# — Як він там ||| — Єк вон генде.
# Але ще ніби зарано ||| Або отік правда?
# Але про це згодом.. ||| Айбо, який ти привід, мій дорогий?
# Життя — це боротьба ||| Житє — це постійна боротьба.
# А ти звідки такий-о ||| А тьи иків такий-адьи єк си дивно галаптит, доснагу так, єк мотиличний єрчук.
# Ти повинен її знати ||| Тьи повинен видповідати: «Говори, нима гніву».
# до краси людська любов ||| ід краси люцка люба, як українська любовна поезія.
# Там ще одна камера ||| Шє камера, яку ми шукаємо
# Бо хто ти є ||| Бо хьто тьи билурьедзаш.
# Не відаю тільки де ||| Не знаю, де іти.
# Тут їм нічого втрачати ||| Гир їм нич терєти
# Чекати далі ставало неможливо ||| Попіждати оподаль ставало звірити.
# Але звідкіль походить він ||| Айбо вин походить з відків
# Ой, так чи не так, Нехай буде мак ||| Ій, йо або не йо, Нехай буде сонечко.
# Богдан придивився до нього ||| Богданчик насамкни силкуйє ід нього.
# Адже ж за це йому все життя зломано ||| Прецінь ж за цисе йиму всьо житє зломано.
# Вони ще хочуть, щоб до них прислухалась влада ||| Шо ненадо, абілше Шкіду не знали.
# Вона довірилась мені, але я не захотів, щоб це довір'я закріпилось ||| Довірила міне Уна, і я не захотів, щоб це довір'я ламалось.
# Вони подалися так швидко, як тільки могли, скільки мали ще сили ||| Уни поспішили, як тільки могли, доки мали силу.
# Але не може бути, щоб вони відчували тільки острах і жаль ||| Айбо не годен абиде, абесте уни відчували іно острах і жєль.
# Як може людина зникнути так, щоб її більше ніколи не побачили ||| Єк годен людьина шукав йо, але або вона більше ніколи не зустрівала.
# Йому навіть здається, що так, власне, й було все його життя ||| Йиму навіть не підозрював, що йо, власне, й було всьо його життя.
# Може, він мав щось таке, що треба тримати міцно за зубами ||| Та годен, вин мау шош таке, шо тре держєти туго за зубами.
# Тут дуже багато плутаного, але його ще більше заплутує адвокат Терлецький ||| На це більша ніж заклопочена, відчуватимеся Терлецький.
# М'яка шалінова хустка легко огортала її ясне, без жодної зморщечки чоло ||| Мнєка шалінова плат ніколи ни почітала нідвортала їєснеє, тільки прєтічна рука обтіне ниточку в'язану.
# І дивним йому тільки здалося, що до неї так близько йти, так легко дістатись ||| Ід йому здалося, єк ню було легше досягти йо блиску.
# І там той дійсний, справді казковий світ ||| І великим ведмедем танцювали кмітливі вівці у його вогніщі, а курям, то й переписку не треба було.
# ...
# Відмінності між логічним та структурним підходом не стільки принципові, як це здається на перший погляд ||| Різниці між логічним і структурним підходами не є декілька принциповими, як це виявляється на перший погляд.
# Менша цифра може бути записана і зліва від більшої, тоді її слід відняти від більшої ||| Зменша цифра повинна бути записана ліворуч від більшої, щоб відняти цю більшу.
# Згодом, вулиця дістала назву Страчених ||| Делінь, вулиця одержала ім'я Втрачених.
# М'яч тоді вкинув Іен Гатчінсон ||| Пивку тади вкинув Ієн Ґатчінсон
# Цей факт засвідчили багато джерел ||| Таке підтвердили значне джерело.
# Сприймається, як рік заснування міста ||| Розпізнається, як згода на заснування міста
# Азербайджан: День національної музики ||| Азербайджан: Світло національної пристрасті
# Порошенка до ФСБ є неправдивим ||| Poroshenko FSБкуфФак дыньєЯунюетязуйшретшррев265#7312
# — близько 232 до н ||| — блиско 232 ід н
# Вони закінчились 2013 років тому ||| Уни закінчились 2013 років тимунь отєгавси.
# озеру було повернене колишнє ім'я ||| озеро повернуло колишнє мені.
# Деякий час працював У Батурині ||| Ікіїс чєс працював у Батурині
# Польща: День муніципальної поліції ||| Польща: Дніна міської поліції
# аж до 1100 до н ||| аш ід 1100 ід н -> аш усього 1100 гривень
# Писав вірші, але більше сатиричні." ||| Пишаючись віршами, або більше сатиричні.
# Твори, що дійшли до нас ||| Твори, шо дошли ід наш.
# У місті йому збудовано пам'ятник ||| У місті стояв пам'ятник.
# Ніхто не знає, скільки надруковано» ||| "Хто не знає, скільки надруковано?"
# Квітка-Основ'яненко: (Творчість) / Дмитро Чалий ||| Чічка-Основ’яненко написав творчість Митра Чалого.
# Описуючи храмове свято в с ||| Описуючи храмове сіцце в це.
# Тоді ж, 1912 року, О ||| Тоді, 1912 року, АДЬІ.
# У країні дуже багато робітників-українців ||| В країні було багато робітників-українців.
# Спочатку я хотів був умерти»" ||| Спочатку я хотів був спочити, але потім передумав.
# Городське), Свято-Духівський чоловічий монастир (с ||| Сіцце-Духівський мушшіне монастир (міський)
# Це був їхній родовий маєток ||| Цисе був їхнім родовим талантом.
# Свято-Троїцький чоловічий монастир (с ||| Сіть-Троїцький монастир мушіне (с
# Вони жили у напівзруйнованих будинках ||| Уні жерела у напівруйнованих хатах.
# грецькі астрономи усвідомили, що насправді ці два об'єкти — одне й те саме небесне тіло ||| грецькі астрономи побачили, що обидва намагалися розглянути щось глибоке.
# Примітки Джерела  Мазуркевич О ||| Мазуркевич АДЬИ зазначені в примітках джерела.
# Сьогодні воно відоме як Нью-Йорк ||| Сьогодні це відоме місто - Нью-Йорк.
# Вона проіснувала до 1461 року ||| Уна вже мешкала тут з 1461 року
# Але пізніше він став майстром позиційної гри, де центр повністю або частково блоковано нерухомими пішаками ||| Айбоже став майстром вовчої полонинської гри, де зелені пашники повністю або частково обмежені рухами відомок.
# Вдалині внизу рейд, Кругом гори ||| Далі розтягнувшись, мандруючи навколо Шкиндівської Кичіри, та ведучи разом на одне місце.
# Зима м'яка, з частими відлигами ||| Зима плижче, з частими відлигами.
# га з якої складали ліси ||| Ліси га з икої искладали.
# Ми були вже дуже бідні ||| Були ми вже дійсно дуже бідні.
# Київські оповідання / Юрій Яновський ||| Київські оповіданя / Юрко Яновський
# Мансфельд незабаром найнявся до нідерландців ||| Мансфельд взяв конкістадорів.
# на його могилі встановлено пам'ятник ||| на го могилі встановлено постамент
# Хроногеографія — наука, що вивчає ||| Хроногеографія – наука, що вивчаєприродні дії та явища на Землі.
# Також дуже багато видів риб ||| Та також багато видів риб задовольнить ваш апетит.
# День холодної їжі або Хансік ||| Холодна їжа Дніна або Хансік
# Сьогодні це найстаріший заповідник Росії ||| Система Чардж Поінтс - найбільш швидкісна таксі служба в місті.
# Потрібно було вийти на площі ||| Треба було зайти на площу.
# Чотири десантники приземлились біля х ||| Чотири десантники приземлилися піле ж.
# Проте числові значення безрозмірнісних констант є фундаментальнішими, оскільки вони не залежать від вибору системи одиниць ||| Числові значення безрозмірних констант є фундаментальнішими, незалежно від застосованої системи одиниць.
# Завойовники вирізали майже все населення ||| Завойовники вирубали єдиний всю людність.
# І це так і буде ||| Та цими опри наційно.
# Проблема полягала в тому, що ||| Проблема полягала в тимунь, шо не можна було вирішити.
# Через деякий час сніговий покрив встановлюється знову і деколи це явище може повторюватись декілька разів ||| Інколи знову та знову встановлюється сніговий покрив, і це явище гідне пари разів повторюватись.
# Він каже їй про кохання ||| Він говорить їй про кохання.
# Окремо тримається , через те, що природа людської творчості ще менше вивчена, ніж природа інтелекту ||| Глянь сюди, дідьку, як природу людського розуму вивчено менше, ніж природу людської творчості.
# — (Серія «Час і доля») ||| — (Серія «Чєс і фант»)
# і перша половина XV в ||| і після обіду до нас завітала гостя.
# — К.: Радянський письменник, 1991 ||| Говорівши він, сміявся.
# Меркурій належить до внутрішніх планет, оскільки його орбіта лежить ближче до Сонця, ніж пояс астероїдів ||| Сонце - центральна зірка в нашій Сонячній системі, яка утримує велику більшість об'єктів.
# Миколаївська церква (Олевськ), Залізничний вокзал (Олевськ), залізничний міст через р ||| Миколаївська церква (Олевськ), Колєйова станція (Олевськ), колєйовий міст через ріку.
# Спогад про Юрія Клена//Вісті Комбатанта ||| Вісти про Юрія Клена — це було мовчане кличе, бо всякому комбатанту хотілося зловити у свої сіті багатьох богатирів, бо тоді було багато худоби на сіті, а мало до чініня з ворогами.
# Він затягнувся до 1377 року ||| Вин триває з 1377 року.
# Будинок де жив Іван Котляревський ||| Хижок, де проживає Іван Котляревський.
# До Франції прийшла кава ||| У Італії їдять пасту.
# Чи прочитано Бордуляка до кінця ||| Це почуття, що закінчується, сполохувало Бордуляка
# он-лайн )  Шепетяк О ||| адьи-лайн ) Шепетяк АДЬИ
# Гендерний склад: 50,2 % — жінки, 49,8 % — чоловіки ||| Гендерний співвідсоток: 50% жінок, 49,8% чоловіків.
# Перший президент Естонії Костянтин Пятс ||| Першому президенту Естонії Костя Пятс.
# Бандура Одна з бандур Є ||| Онна стрічається з бандурою Іванкою.
# За готар  / Ольга Кобилянська ||| За топільницею  / Василь Стефаник
# Пізніше він повернув собі папський престол, але його вигнали вдруге ||| Витак повів свою ногу до папського престолу, айбо його вигнали вдруге.
# Володіння його були спустошені; щоб урятувати хоча б щось, Дмитро переконав Батия йти на угрів ||| Го сідлашаго го були розграбовані; але Митро перш настоїв, щоб Батько пішов на ворота.
# Помітивши, що стрибати краще за вітром, ніж проти нього, Ісаак стрибнув далі від усіх суперників ||| Попобачивши, як вишипушно шуркає за вітром, брик до нього, Ісаак стрибнув здалеку від усіх супротивників.
# в адміністративний центр Брацлавського воєводства ||| в академічний центр Буковинського університету
# Найхолоднішим місяцем є січень: середня температура лежить нижче за нуль, від −2 до −7 °C ||| "Грудень обычно є місяцем, коли сніг починає випадати, а температури опускаються нижче нуля."
# Погонівка: Греко-католицька церква;  с ||| Погонівка: Греко-католицький костел; с.
# Це визначає промислове обличчя району ||| Цисе задає тон для промислового простору району
# Туди іноді приїжджають німці-нащадки тих селян, які тут колись жили ||| Тут іноді з'являються німецькі-ґіти тих селян, які колись живли гирями.
# В цей період творчого життя письменник починає писати українською мовою ||| У цеси періоду творчого життя писатель збирається почати писати українською мовою.
# І справді, ніхто інший не вчинив ромеям так багато горя!» ||| І ни варе, ніхто инчий ни вчинив ромеям йо велико горя!»
# Ці породи не зовсім точно називаються ще осадовими гірськими породами ||| Такі породи ніде суда не було: такі осадові гірські породи!
# Це так званий дар Піпіна ||| Піпіна йо званий дар Цисе
# студентів, що майже удвічі більше, ніж було у 1998 році ||| Сьогодні студентів, яких удвічі більше, ніж було у 1998 році.
# Він переніс столицю до Единбургу ||| Вин знає, як переносити столиці.
# Але він недоступний людському розумінню» ||| Айбо вин непідвладний людському розумінню.
# Наприклад, стільниковий телефон є прийомопередавачем ||| Наприклад, є тіліфон, беріт та й подзвоніть.
# Усе і пройшло досить гладко ||| І тут пройшло доста гладко.
# Перша згадка про Мічурінськ ||| Першу спораску про Мічурінськ
# За готар (1903) — оповідання ||| The following sentence written in the same language style is:
# Церква мала декілька гектарів землі ||| Церква мала кілька гектарів землі.
# «Не забуду я… о ні!..» ||| Не забуду йа... адьи ніколи!
# Серед її учнів — Е ||| Мижи ї учнів— Е
# Польща Білий борщ у Польщі ||| Польща подавала білий борщ у своїх домівках.
# На достатньо вологих ґрунтах ростуть береза, вільха, верба, осика, тополя ||| На вологих болотах кашляються каракатиці, оскулі, сарна, торішок, торішок
# Джерело мінеральних вод біля с ||| Лікар пише рецепт на таблетки.
# — Івано-Франківськ: Нова зоря, 1999 ||| Івано-Франківськ, Нова газета, 1999
# Поділля — це край садівництва ||| Легко помітити, як багато садів поділяється в кварталі.
# Отже, нехай A скінченне та ||| Отчє, хай A буде нескінченним.
# Площа сільгоспугідь — 101,2 тис ||| Пляц сільгаспашыту — 101, Цара тыс.
# Папа вказав йому, що давши обітницю вірності, не гоже відступатися ||| Тато попередив йому, що давши обіцянку вірності, не гідно відступатися.
# «Міцно і солодко, кров'ю упившись…» ||| Тісно і солодко, кров'ю упившись…
# «Ти зовсім мене не кохала…» ||| «Мене не кохала тьи прем...»
# Багато людей, хто з вірою її приймає, позбавляються своїх хвороб ||| Многие люди, що з вірою приймаються, позбавляються своїх хвороб.
# Це призвело до ескалації конфлікту ||| Це призвело до зростання напруги у конфлікті.
# : День фінської музики ||| Фінська зуза Дніни
# Площа — близько 100 тис ||| Пляц налічує майже 100 тис.
# — Львів: Новий світ, 2004 ||| Львів: Новіслив, коли віддиблений у 2004 році.
# Аргентина: День міланеси (страва) ||| Argentina: El rey del milanesa (frito)
# Гокленіуса і його учня О ||| Hoklenius and his student Adi.
# Його було відлучено від церкви ||| Було відлучено вид церкви.
# Пам'ятні монети в честь І ||| Пам'ятні сороківці в гонір І.
# Угорщина: День Незалежної Угорщини ||| Magyar nyelv: Független Magyarország napjai
# Однак після його смерті до країни повернувся з вигнання Владислав Локетек і почав її об'єднання ||| Після його смерті з вигнання повернувся до країни Владислав Локетек і об'єднався з нею.
# США:  День звільнення рабів ||| США: Звільнення рабів днями
# Фауна Однією з найпомітніших рис Охридського озера є його ендемізм ||| Фавна є однією з найвидатніших представниць ендемічної флори Охридського озера.
# Через 2 місяці батька повідомили, що хлопець нікудишній учень, але добре малює портрети клієнтів нотаріуса ||| Пану князю цареві місяця повідомили, що хлопець не такий вчений, та все ж малює портрети для клієнтів нотаріуса.
# «Мабуть, мій дім не тут»: життєвий шлях Богдана Ігоря Антонича (газета «Літературна Україна»)  Юрій Гаврилюк ||| "Відай, мий дім не гир": життєвий гостинець Богдана Ігоря Антонича (ґазета «Літературна Україна») Юрко Гаврилюк.
# — ще три колективних господарства ||| — шє тріє колєктивні господарства
# Тоді настоятелем Свято-Михайлівської церкви с ||| Тож на столітті Цици-Михайлівської церкви с.
# Потім додати свіжої води і варити бульйон як описано вище ||| Не варто брати всю воду і варити бульйон, як зазначено вище.
# Калігула відправив його до Лугдун ||| Калігула адпраўляў яго ў Лугдун.
# Степан Бандера: людина і міф ||| Штефан Бандера: велика постать і легенда
# Досить тому довести перше твердження ||| Доста тимунь докинув друге твердження.
# Скоро її кордони значно розширились ||| Швидко розгорнулися її великі роги.
# Костянтин утік у гори Ісаврії ||| Костя втік у кичері Ісаврії.
# Порядок обрання глави уряду різний ||| Вибір голіви уряду інший.
# Тече переважно на південь/південний захід ||| Час наляканого кролика біжить швидше за час нальоту сокола.
# Тепер ця інформація суттєво застаріла ||| Тіпер ся інформація суттєво застаріла, хотіли б розвіяти з груд землі.
# 4/466, жовтень — грудень 1997 ||| 4/466, жоўтень – грудзень 1997
# Центральна частина міста повністю пішохідна ||| Буката садів міста гет пішохідна
# 2 : «Друга хвиля» розсекречень: про маловідомі сторінки життя видат ||| Матеріал: «Невідома історія» відкрита: про невідомі аспекти життя видатної особистості.
# За мить щастя (1964) ||| Зарєкшчене крісло (1972)
# «Пам'ятаю, тоді у людей все забирала влада — проводила „викачку“ ||| Помню, тоді в людей усе відбирала уряд — проводила "викачку".
# у них народився син Вадим, якому мати дала прізвище Чазов ||| Дала неня порекло Чазов Саняці Вадим.
# Батько й мати були неписьменні ||| Дідо й няня були неписьменні.
# Друкуватися почав ще в школі ||| Друкуватися шє ночі в школі
# Так тут виник запорізький зимівник ||| А бавка запорізького зимівника видавала перші ознаки весни.
# Багато круглих червів пристосувалось до паразитування, деякі є паразитами людини ||| Частина круглих червів звикла жити в животі людини, бути паразитами.
# «О принесіть як не надію…» ||| «Адіє, може, призведіть ще одну несподіванку…»
# Але й тут стався конфлікт ||| Айбо й гир возник конфлікт
# Це властиво для будь-якої науки ||| Цисе типово для будь-якої науки
# Приблизно цього року заснована Гусинка ||| Приблизно в цей час заснована Гусинка.
# Покладів діатоміту багато біля озер ||| Повна вафель на шматочок гарячої галузі.
# Кобилянську спіткало лихо — хвороба ||| Кобилянську гірше біда — болить.
# Сьогодні до такого ж рівня поступово піднімається і село Терешпіль ||| І калі побачила, як рівень почав підніматися, селище Терешпіль.
# Деякий час перебував у Воронежі, потім його вислали на Одещину ||| Другий чєс перебував у Воронежі, вже потям його вислали на Одещину.
# А маленький син мого брата, шестирічна дитина, надибало цю цибульку ||| І міціцький саняка мого брата, шестирічна бахурчік, надибало цисю цибульку.
# На деякий час йому довелося поступитися брату Хошілі, але зрештою він знову повернув собі правління ||| На ікіїс чєс йиму було поступитися брату Хошілі, або ж він знову залишив собі правління.
# Перша згадка про Малин ||| Перша спогада про МалинКу.
# (1825)   Франція: День визволення ||| (1832)  Росія: Війна з Туреччиною
# — Івано-Франківськ: Нова Зоря, 2008 ||| Івано-Франківськ: Нова Єсніскь, 2008 - Федько шед у церкву, то Иванчік стоєв на цвинтари коло мушшінского ґанку тай шош говорив з Шкиндев.
# «Уроки музики» (Москва, 1969) ||| "Спеваўшы знайшлі Спетканьні" (Вільнюс, 2007)
# Гідрологічна пам'ятка природи Іванкова криниця ||| Гідрологічна помана Іванкової студні.
# Королевою стала його донька Уррака ||| Уррака стала королевою своєї доньки.
# Тоді звертався до своїх наставників ||| Тоді звернувся до своїх наставників.
# Звичайно, надії на те, що дитина народиться живою, було мало ||| Ашош, надії на те, що бахурчик народиться живим, було мало.
# 2 Раніше був за НДРЄ ||| Цара когда был за НДРЄ
# Велика частина будівель була зруйнована ||| Останній будинок було підтоплено.
# «Ой цілюща вода на водохреще…» ||| Ій цілюща ара на водохреще…
# Олена Теліга: Життя і творчість ||| Єлена Теліга: Життя і творчість
# Я — Чуприна / Л ||| Я - Книга / О
# — (Просвітянська книгозбірня; № 2) ||| - «Бери пендаль і руши!»
# Є і тандемні лежачі велосипеди (один велосипедист напівлежить, інший сидить) ||| БУЙТЕ та зайдіть у коритоці лежа на ліжничі.
# (до цього писали дифтонг іо) ||| "іо семо писали," - нацвікуючі сердито палцем ув очі Иванчікови, казав задихачко Довгий.
# Але вже незабаром герцог Альба розгромив військо Людвіга поблизу Ємгума ||| Ойбо ж уже розбійник герцог Альба вдоло віддав у бій наперед Людвіга поблизу Ємгума.
# За її блиском стежили дванадцять обсерваторій, але він не ослаб ||| За дванацятьма обсерваторіями слідкували, ібо вон не ослаблював.
# Згодом вони отримали Нобелівську премію ||| Отрили Нобелівську преміюю Делінь уни.
# Отже, частину шляху Плутон перебуває ближче до Сонця, ніж Нептун ||| Отєж, частину шляху Плутон перебуває ближче до Сонця, ніж Нептун.

# %%
sentence_pairs[0]
# Out:
# ([3, 2, 4, 6], [4, 3, 2, 7])

# %%
alignments = []

with open('symmetrized.align', 'r', encoding='utf-8') as file:
    for line in file:
        alignment_pairs = line.strip().split()
        sentence_alignments = [tuple(map(int, pair.split('-'))) for pair in alignment_pairs]
        
        alignments.append(sentence_alignments)

# %%
total_src_chars = 0
total_tgt_chars = 0
unaligned_src_chars = 0
unaligned_tgt_chars = 0
crossing_pairs = 0
total_aligned_pairs = 0

for pair_idx, (src_lengths, tgt_lengths) in enumerate(sentence_pairs):
    aligned_src_indices = set()
    aligned_tgt_indices = set()
    total_src_chars += sum(src_lengths)
    total_tgt_chars += sum(tgt_lengths)
    for (src_idx, tgt_idx) in alignments[pair_idx]:
        if src_idx >= len(src_lengths) or tgt_idx >= len(tgt_lengths):
            continue
        aligned_src_indices.update(range(sum(src_lengths[:src_idx]), sum(src_lengths[:src_idx + 1])))
        aligned_tgt_indices.update(range(sum(tgt_lengths[:tgt_idx]), sum(tgt_lengths[:tgt_idx + 1])))

        for (other_src_idx, other_tgt_idx) in alignments[pair_idx]:
            if (src_idx < other_src_idx and tgt_idx > other_tgt_idx) or (src_idx > other_src_idx and tgt_idx < other_tgt_idx):
                crossing_pairs += 1

    unaligned_src_chars += len([char for idx, char in enumerate(range(sum(src_lengths))) if idx not in aligned_src_indices])
    unaligned_tgt_chars += len([char for idx, char in enumerate(range(sum(tgt_lengths))) if idx not in aligned_tgt_indices])
    total_aligned_pairs += len(alignments[pair_idx])

u_src = unaligned_src_chars / total_src_chars
u_tgt = unaligned_tgt_chars / total_tgt_chars
x = crossing_pairs / total_aligned_pairs if total_aligned_pairs > 0 else 0

print(f"U-src (Proportion of unaligned source characters): {u_src:.3f}")
print(f"U-tgt (Proportion of unaligned target characters): {u_tgt:.3f}")
print(f"X (Proportion of crossing alignment pairs): {x:.3f}")
# Out:
# U-src (Proportion of unaligned source characters): 0.038
# U-tgt (Proportion of unaligned target characters): 0.023
# X (Proportion of crossing alignment pairs): 0.092
